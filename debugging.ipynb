# %%
import csv
import os
import re

import pandas as pd
import collections

import requests
import wget
import urllib.request
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.ishares.com/us/products/239726/ishares-core-sp-500-etf"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

csv_link = soup.find("a", text="Detailed Holdings and Analytics")
csv_url = "https://www.ishares.com" + csv_link["href"]

print(csv_link["href"], csv_url)
# Out:
# /us/products/239726/ishares-core-sp-500-etf/1467271812596.ajax?fileType=csv&fileName=IVV_holdings&dataType=fund https://www.ishares.com/us/products/239726/ishares-core-sp-500-etf/1467271812596.ajax?fileType=csv&fileName=IVV_holdings&dataType=fund
# /tmp/ipykernel_4228/1961116290.py:8: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   csv_link = soup.find("a", text="Detailed Holdings and Analytics")

# %%
req = requests.get("https://www.ishares.com/uk/individual/en/products/253742/ishares-nikkei-225-ucits-etf")

# %%
<div class="holdings fund-component-data-export">
<a class="icon-xls-export" href="/uk/individual/en/products/253742/ishares-nikkei-225-ucits-etf/1506575576011.ajax?fileType=csv&amp;fileName=CNKY_holdings&amp;dataType=fund" data-link-event="holdings:holdings">Detailed Holdings and Analytics</a>
</div>

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en" prefix="og: http://ogp.me/ns#" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>Exchange-Traded Funds (ETFs) | iShares UK – BlackRock</title>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="" name="keywords"/>
# <meta content="iShares by BlackRock, the largest provider of exchange-traded-funds (ETFs) in the world, provides exposure to various asset classes. Discover how." name="description"/>
# <meta content="Exchange-Traded Funds (ETFs) | iShares UK – BlackRock" name="articleTitle"/>
# <meta content="iShares by BlackRock, the largest provider of exchange-traded-funds (ETFs) in the world, provides exposure to various asset classes. Discover how." name="pageSummary"/>
# <meta content="Exchange-Traded Funds (ETFs) | iShares UK – BlackRock" property="og:title"/>
# <meta content="website" property="og:type"/>
# ...

# %%
soup = BeautifulSoup(req.content, "html.parser")
suburl = soup.find_all("href", {"class": "icon-xls-export"})

print(suburl)
# Out:
# []

# %%
req = requests.get("https://www.ishares.com/uk/individual/en/products/251867/ishares-msci-japan-ucits-etf-acc-fund").text

# %%
soup = BeautifulSoup(req, "html.parser")

# %%
https://www.ishares.com/uk/individual/en/products/251867/ishares-msci-japan-ucits-etf-acc-fund/1506575576011.ajax?fileType=csv&fileName=SJPA_holdings&dataType=fund

# %%
soup.select("div.holdings.fund-component-data-export > a.icon-xls-export")[0].get("href")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 soup.select("div.holdings.fund-component-data-export > a.icon-xls-export")[0].get("href")
#
# IndexError: list index out of range

# %%
soup.find("div", {"class": "holdings.fund-component-data-export"})
